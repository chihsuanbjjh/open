# %% [markdown]
# # 迴圈是什麼？
# * 迴圈主要是執行重覆的指令，減少重覆出現的程式碼
# * 語法：for  ______ in ______:

# %% [markdown]
# * 不使用迴圈的寫法

# %%
print('Python')
print('Python')
print('Python')
print('Python')
print('Python')
# Out:
# Python
# Python
# Python
# Python
# Python

# %% [markdown]
# 五行的 print('Python') 程式就會執行五次的 print('Python')

# %% [markdown]
# * 使用迴圈

# %%
for i in range(5):
    print('Python')
# Out:
# Python
# Python
# Python
# Python
# Python

# %% [markdown]
# 說明：
# * i：任意的變數名稱，以英文命名，可儘量取閱讀性高的名稱，例如：count(次數)、rotate_angle(旋轉角度)、lap(圈)
# * range(5)：一個從0~4的數列 [0, 1, 2, 3, 4] ※不包含5
#
# for i in range(5):<br>
# ->意思是 i 從 [0, 1, 2, 3, 4] 裡從頭依序拿數字然後再執行下面的程式區塊

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# 假設學校操場一圈200公尺，小明想用寫個程式計算跑了5圈與每圈累積的距離

# %%
for lap in range(5):
    print(f'跑了 {lap} 圈，總長度為 {lap*200} 公尺')
# Out:
# 跑了 0 圈，總長度為 0 公尺
# 跑了 1 圈，總長度為 200 公尺
# 跑了 2 圈，總長度為 400 公尺
# 跑了 3 圈，總長度為 600 公尺
# 跑了 4 圈，總長度為 800 公尺

# %% [markdown]
# 如果變數與程式區塊無關的話，那就變成單純控制執行程式區塊的『次數』
# * for i in range(5):  -> 執行5次
# * for i in range(10): -> 執行10次

# %% [markdown]
# # 練習1

# %%
# 請簡化下列程式碼
print('Python')
print('Python')
print('Python')
print('Python')
print('Python')
# Out:
# Python
# Python
# Python
# Python
# Python

# %%
# for count in range():

# %% [markdown]
# # 練習二

# %%
print(1)
print(2)
print(3)
print(4)
print(5)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
# for num in range():

# %% [markdown]
# # 練習三

# %%
print(1)
print(2)
print(3)
print(4)
print(5)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
# for num in range():
